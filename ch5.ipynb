# %% [markdown]
# ## written material
#
# going to grab this data from gh : https://raw.githubusercontent.com/stefanbund/py3100/main/ProductList_118.csv

# %%
import pandas as pd

# %%
variable = 'x'
print(variable)
# Out:
# x

# %%
url =  'https://raw.githubusercontent.com/stefanbund/py3100/main/ProductList_118.csv'
url_m = 'https://raw.githubusercontent.com/stefanbund/py3100/main/matrix.csv'

# %%
df_m = pd. read_csv(url_m)

# %%
list = ['a', 'b', 'c', 'd']

# %%
list.append('e')

# %%
list #mutable array of data
# Out:
# ['a', 'b', 'c', 'd', 'e', 'e']

# %%
dual_list = list

# %%
dual_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'e']

# %%
print(url)
# Out:
# https://raw.githubusercontent.com/stefanbund/py3100/main/ProductList_118.csv

# %%
df_ulta = pd.read_csv(url)

# %%
  df_ulta
# Out:
#       Product Name  New York 5348  Delaware 5795  Mississippi 2167  \
# 0    Product 98294            199            376               744
# 1    Product 98295            209            915               749
# 2    Product 98296            711            837               154
# 3    Product 98297            683            949               834
# 4    Product 98298            538            263               532
# ..             ...            ...            ...               ...
# 828  Product 99122            834            551               703
# 829  Product 99123            718            567               261
# 830  Product 99124            628             12               174
# 831  Product 99125            501             64               269
# 832  Product 99126            562            389               492
#
#      Connecticut 353  New Hampshire 6876  Nebraska 2660  Massachusetts 3351  \
# 0                337                 325            902                 938
# 1                734                 681            423                 586
# 2                295                  99            646                 243
# 3                751                 476            357                  70
# 4                253                 990            980                 257
# ..               ...                 ...            ...                 ...
# 828              477                 773            465                 135
# 829              734                  26            645                 994
# 830              594                 300            219                 623
# 831              125                 132            726                  75
# 832              859                 880            750                 106
#
#      Oregon 4969  New Mexico 6120  ...  North Dakota 4133  Nevada 2292  \
# 0            704              331  ...                667          694
# 1            497              292  ...                457          749
# 2            548              334  ...                704          993
# 3            667               44  ...                 86          823
# 4            240              785  ...                 62          484
# ..           ...              ...  ...                ...          ...
# 828           48              717  ...                290          799
# 829          947              919  ...                 14          635
# 830          959              979  ...                613          778
# 831          196              226  ...                181          856
# 832          426              956  ...                652          719
#
#      Alaska 6502  Iowa 3449  Florida 7295  Hawaii 5042  Michigan 6982  \
# 0            549        702           640          237            897
# 1            838        448           688            2            221
# 2            232        598           356          706            101
# 3            959        755           184          302            747
# 4            968        833           812          983            314
# ..           ...        ...           ...          ...            ...
# 828          814        469           179          989            526
# 829          834        870           873          436            684
# 830          433        513           739          351            745
# 831          636        785           473          780            143
# 832          557        782           548          160            800
#
#      Massachusetts 9737  Idaho 4519  Iowa 5253
# 0                   378         489        168
# 1                   276         948        592
# 2                   700         400        387
# 3                   636         852        649
# 4                   779         789        887
# ..                  ...         ...        ...
# 828                 729         359        502
# 829                 271         620        652
# 830                 820         705        580
# 831                 456        1000        218
# 832                 638         935        426
#
# [833 rows x 1336 columns]
